# %% [markdown]
# <a href="https://colab.research.google.com/github/apolo-ms/PA_python/blob/main/aula_pa_1c/cois_sem_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade1=int(input('digite a primeira idade: '))

idade2=int(input('digite a segunda idade: '))

iade1=(idade1 > idade2)

iade2=(idade2 < idade1)
print(iade1)

print(iade2)

print("a idade um sera a maior? ", iade1)
# Out:
# digite a primeira idade: 70
# digite a segunda idade: 60
# True
# True
# a idade um sera a maior?  True

# %%
idade=int(input('qual a sua idade: '))
senha=int(input('qual sua senha: '))
entrar=idade>=18 and senha==1234
print('acesso',entrar)
# Out:
# qual a sua idade: 19
# qual sua senha: 1234
# acesso True

# %%
numero=int(input('digite um numero: '))
est=numero>=10 and numero<=50
print('o numre esta entre 10 e 50? ',est)
# Out:
# digite um numero: 100
# o numre esta entre 10 e 50?  False

# %%
preço=float(input("digite o preço "))
saldo=float(input("digite o saldo "))
digite=int(input("digite o cupom "))
pode= preço<=saldo
print(pode)
cupom=digite==1234 and preço>=saldo
print(cupom)
print("pode comprar o produto com o saldo ?", pode)
print("pode comprar o produto com o cupom ?", cupom)

# %%
numero=int(input(" digite o numero"))
par=numero%2==0
print(par)
positivo=numero>0
print(positivo)
print("o numero é par ?", par)
print("o numero é positivo ?" , positivo)

# %%
idade=int(input("digite a idade"))
esta=idade>=13 and idade<=17
print("a pessoa tem entre 13 a 17 anos ?", esta)

# %%
adm=int(input('digite 1 se voce é adm ? ' ))
senha=int(input('digite a senha ' ))
adm==1
senha = senha==1234
print("pode acessar o sistema ?", senha)

# %%
nota=float(input("digite a nota "))
presente=int(input("digite 1 se esta presente "))
aprovado=nota>=6
presente==1
print("o aluno foi aprovado ?", aprovado)

# %%
velocidade=float(input("digite a sua velocidade "))
limite=80
multa=velocidade>limite
print("voce foi multado ?", multa)

# %%
convite=int(input("digite 10 se voce tem o convite "))
idade=int(input("digite a sua idade "))
convite==10
print("pode entrar no evento ?", idade)
