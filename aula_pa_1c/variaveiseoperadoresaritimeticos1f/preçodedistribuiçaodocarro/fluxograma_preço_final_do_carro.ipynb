# %% [markdown]
# <a href="https://colab.research.google.com/github/apolo-ms/PA_python/blob/main/aula_pa_1c/variaveiseoperadoresaritimeticos1f/pre%C3%A7odedistribui%C3%A7aodocarro/fluxograma_pre%C3%A7o_final_do_carro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("conta do valor do carro")
#custo de fabricação
custo = float(input('digite o custo de fabricação: '))
#operação matematica
valdist=(custo/100)*28
valimp=(custo/100)*45
#custo final
custfinal=custo+valdist+valimp
print("o custo final do carro sera ",custfinal)
# Out:
# conta do valor do carro
# digite o custo de fabricação: 50000
# o custo final do carro sera  86500.0
