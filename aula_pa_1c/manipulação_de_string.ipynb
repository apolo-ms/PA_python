# %% [markdown]
# <a href="https://colab.research.google.com/github/apolo-ms/PA_python/blob/main/aula_pa_1c/manipula%C3%A7%C3%A3o_de_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "Hello World"
print(len(x))
# Out:
# 11

# %%
txt = "Hello World"
x = txt[0]
print(x)
# Out:
# H

# %%
txt = "Hello World"
x = txt[:5]
xi=x[2:]
print(xi)
# Out:
# llo

# %%
txt = "Hello World"
txt = txt.upper()
print(txt)
# Out:
# HELLO WORLD

# %%
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"
x=txt.count('de')
print(x)
# Out:
# 3

# %%
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"
x=txt.split(',')
print(x)
# Out:
# ['Eu gosto de vijar', ' tomar vinho', ' de estudar estudar programação', ' de estudar Pyhon']

# %% [markdown]
# 4 bagulho

# %%
inp = str(input('digite seu nome completo: '))
x=inp.upper()
print(x)
xi=inp.lower()
print(xi)
xis=inp.split(' ')
print(xis)
ei = inp.find(' ')
if ei != -1:
    pn = inp[:ei]
else:
    pn = inp
print( pn)
# Out:
# digite seu nome completo: ronaldo de ronaldo junior
# RONALDO DE RONALDO JUNIOR
# ronaldo de ronaldo junior
# ['ronaldo', 'de', 'ronaldo', 'junior']
# ronaldo

# %%
tt='edson'
vogal = 0
for x in tt:
  if x == 'a' or x == 'e'or  x == 'i'or  x == 'o'or  x == 'u':
    vogal = vogal+1
print(vogal)
# Out:
# 2
