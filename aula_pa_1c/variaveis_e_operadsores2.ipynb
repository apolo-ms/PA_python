# %% [markdown]
# <a href="https://colab.research.google.com/github/apolo-ms/PA_python/blob/main/aula_pa_1c/variaveis_e_operadsores2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota1 = float(input("qual a primeira nota: "))
nota2 = float(input("qual a segunda nota: "))
soma1 = nota1 + nota2
resultado  = soma1 /2
print('a media e',resultado)

# %%
c = float(input('qual a temperatura em celcius: '))
r1 = c * 1.8
f = r1 + 32
print ('em f o resultado e ', f)

# %%
f = float(input('escreva em fha'))
r1 = f - 32
c = r1 /1.8
print('o resultado e ',c)

# %%
valor1 = float(input('qual o valor do item: '))
quantidade1 = int(input('qualo a quantidade'))
r1 = valor1 * quantidade1
print('o valor total e', r1)
# Out:
# qual o valor do item: 10
# qualo a quantidade200
# o valor total e 2000.0
