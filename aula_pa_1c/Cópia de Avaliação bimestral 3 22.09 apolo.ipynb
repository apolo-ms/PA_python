# %% [markdown]
# Coloque seu nome aqui:apolo moreno de souza

# %% [markdown]
# **Atividade Avaliativa **
#
# Enunciado:
#
# Crie um programa em Python para avaliar uma competição de bandas de música. O programa deve:
#
# Perguntar a quantidade de bandas participantes (mínimo 3).
#
# Perguntar o nome de cada banda.
#
# Para cada banda, receber as notas de 5 jurados (valores de 0 a 10).
#
# Calcular a média das notas de cada banda e armazenar o resultado em um dicionário, onde a chave será o nome da banda e o valor será a média das notas.
#
# Ao final, mostrar:
#
# A média de cada banda.
#
# O nome da banda vencedora (a que tiver maior média).

# %%
qtd = 0
while qtd < 3:
    qtd = int(input("Quantas bandas vão participar? (mínimo 3): "))
    if qtd < 3:
        print("É necessário pelo menos 3 bandas!")

resultados = {}

for i in range(qtd):
    banda = input("Digite o nome da " + str(i+1) + "ª banda: ")
    notas = []
    for j in range(5):
        nota = -1
        while nota < 0 or nota > 10:
            nota = float(input("Nota do jurado " + str(j+1) + " (0 a 10): "))
            if nota < 0 or nota > 10:
                print("Nota inválida! Digite entre 0 e 10.")
        notas.append(nota)
    media = sum(notas) / 5
    resultados[banda] = media

print("=== Resultados ===")
for banda in resultados:
    print(banda, ": média", round(resultados[banda], 2))

vencedora = ""
maior_media = -1
for banda in resultados:
    if resultados[banda] > maior_media:
        maior_media = resultados[banda]
        vencedora = banda

print("Banda vencedora:", vencedora, "com média", round(maior_media, 2))
# Out:
# Quantas bandas vão participar no minimo tres: 3
#
# Digite o nome da 1ª banda: eds
# Nota do jurado 1 (0 a 10): 1
# Nota do jurado 2 (0 a 10): 2
# Nota do jurado 3 (0 a 10): 3
# Nota do jurado 4 (0 a 10): 4
# Nota do jurado 5 (0 a 10): 5
#
# Digite o nome da 2ª banda: 6
# Nota do jurado 1 (0 a 10): 678
# Nota inválida! Digite entre 0 e 10.
# Nota do jurado 1 (0 a 10): 10
# Nota do jurado 2 (0 a 10): 2
# Nota do jurado 3 (0 a 10): 9
# Nota do jurado 4 (0 a 10): 6
# Nota do jurado 5 (0 a 10): 6
#
# Digite o nome da 3ª banda: edss
# Nota do jurado 1 (0 a 10): 1
# Nota do jurado 2 (0 a 10): 2
# Nota do jurado 3 (0 a 10): 3
# Nota do jurado 4 (0 a 10): 10
# Nota do jurado 5 (0 a 10): 10
# eds: média 3.00
# 6: média 6.60
# edss: média 5.20
#
# Banda vencedora: 6 com média 6.60

# %% [markdown]
# ##### 1
# # Enunciado:
#
# Crie um programa que conte quantas vezes cada palavra aparece em uma frase.
#
# Pedir ao usuário para digitar uma frase
#
# Imprimir a palavra e quantas vezes ela aparece

# %%
frase = input("Digite uma frase: ")
palavras = frase.lower().split()
contagem = {}
for palavra in palavras:
    if palavra in contagem:
        contagem[palavra] += 1
    else:
        contagem[palavra] = 1
print("contagem:")
for palavra, qtd in contagem.items():
    print("{palavra}: {qtd}")
# Out:
# Digite uma frase: aplo gosta apolo
# contagem:
# {palavra}: {qtd}
# {palavra}: {qtd}
# {palavra}: {qtd}

# %% [markdown]
# Enunciado:
#
# Crie um programa em python que imprima números pares
#
# Pedir o usuário para digitar uma lista com mínimo 10 números
#
# Criar uma nova somente com numeros pares
#
# Imprimir números pares

# %%
numeros = []
while len(numeros) < 10:
    numeros = list((int, input("digite 10 numeros com espaço entre eles: ").split()))
    if len(numeros) < 10:
        print("digite pelo menos dez numeros")

pares = []
for n in numeros:
    if n % 2 == 0:
        pares.append(n)
print(pares)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 2
#       1 lista=[]
# ----> 2 while lista < 10:
#       3     lista=int(input(""))
#       4     print(lista)
#
# TypeError: '<' not supported between instances of 'list' and 'int'
