# %% [markdown]
# <a href="https://colab.research.google.com/github/apolo-ms/PA_python/blob/main/aula_pa_1c/coisas_com_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ano = int(input('digite o ano que voce deseja saber se e bissexto: '))
if ano % 4 and ano % 100 !=0 or ano % 400 == 0:
  print('esse ano e bissexto')
else:
  print('não e bissexto')
# Out:
# digite o ano que voce deseja saber se e bissexto: 2020
# não e bissexto

# %%
from pickle import encode_long
idade = int(input('qual sua idade: '))
if idade >=18 and idade <=24:
  print('voce esta dentro da faixa etaria permitida no nosso clube secreto pode entrar!!!!')
elif idade>=15 and idade<=17:
   print('voce esta quase podendo entrar no clube secreto')
else:
  print('voce não pode entrar no clube secreto :(')
# Out:
# qual sua idade: 15
# voce esta quase podendo entrar no clube secreto

# %%
numero = float(input('digite um numero: '))
if numero >= 32.5 and  numero <= 58.7:
 print('voce acertou um numero entre os selecionados')
else:
  print('voce nao acertou um numero entre os selecionados')
# Out:
# digite um numero: 12
# voce nao acertou um numero entre os selecionados

# %%
num = int(input('digite um numero: '))
if num%2 == 0:
  print('o numero e par')
else:
  print('o numero e impar')

# %%
triangulo=0
equilatero=0
escaleno=0
L1=int(input("digite o lado  do l1 "))
L2=int(input("digite o lado do L2 "))
L3=int(input("digite o lado do L3 "))
if triangulo == (L1+L2>L3) and (L2+L3>L1) and (L3+L1>L2):
  print('triangulo')
elif equilatero ==(L1==L2==L3):
  print(equilatero)
elif escaleno ==L1!= L2 !=L3:
 print(escaleno)
else:
  print('isoceles')
# Out:
# digite o tres lado do triangulo, digite o lado  do l1 10
# digite o lado do L2 10
# digite o lado do L3 10
# isoceles

# %%
peso = float(input('qual seu peso: '))
altura = float(input('qual sua altura: '))
imc = (peso/altura**2)
if imc >= 18.5:
  print('abaixo do peso')
elif imc >=18.5 and imc<=24.9:
 print('peso normal')
elif imc >=25 and imc <= 29.9:
  print('sobrepeso')
elif imc >=30 and imc<=39.4:
  print('obesidade grau 1')
elif imc >=35 and imc <= 39.9:
 print('obesidade grau 2')
elif imc >=40:
  print('obesidade grau 3')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-141b7c378ef2> in <cell line: 0>()
# ----> 1 peso = float(input('qual seu pesso: '))
#       2 altura = float(input('qual sua altura: '))
#       3 imc = (peso/altura^2)
#       4 if imc >= 18.5:
#       5   print('abaixo do peso')
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
idade= int(input('qual sua idade: '))
alt = float(input('qual sua altura: '))
if altura >= 1.75 and idade >=18:
  print('pode competir')

# %%
salario = float(input("digite o salario "))
emprestimo = float(input("digite o valor do emprestimo "))
parcelas = int(input("digite a quantidade de parcelas "))
salario*0.3
emprestimo/parcelas
if salario*0.3>=emprestimo/parcelas:
  print("pode fazer o emprestimo")
else:
  print("não pode fazer o emprestimo")
